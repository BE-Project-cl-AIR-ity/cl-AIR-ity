# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime as dt
import json

# %%
dataset = pd.read_csv("/Users/dhruv/Downloads/BE_PROJECT_CSV/PyScript/datasetRawAdded2.csv", usecols =['Date_UTC','entry_id', 'PM1','PM25', 'PM10', 'CO', 'Temp', 'Humidity', 'Pressure', 'MAXT','MINT','SPD','WDG','CLD'])
df = pd.DataFrame(dataset)

# %%
df.columns = ['Date_UTC','entry_id', 'PM1','PM25', 'PM10', 'CO', 'Temp', 'Humidity', 'Pressure', 'MAXT','MINT','SPD','WDG','CLD']

# %%
# print("Replacing blanks with NaN:\n")
df = df.replace(r'^\s*$', np.NaN, regex=True)
df[['PM1','PM25', 'PM10', 'CO', 'Temp', 'Humidity', 'Pressure','MAXT','MINT','SPD','WDG','CLD']] = df[['PM1','PM25', 'PM10', 'CO', 'Temp', 'Humidity', 'Pressure','MAXT','MINT','SPD','WDG','CLD']].apply(pd.to_numeric)

# %%
df.head()
# Out:
#    Date_UTC  entry_id  PM1  PM25   PM10    CO       Temp   Humidity  \
# 0  10/07/15         0  NaN  45.0  106.0  11.0  25.585000  76.833333
# 1  11/07/15         1  NaN  48.0  137.0   7.0  25.710833  74.291667
# 2  12/07/15         2  NaN  59.0  101.0  10.0  26.253333  71.291667
# 3  13/07/15         3  NaN  57.0  155.0  11.0  26.346250  72.541667
# 4  14/07/15         4  NaN  58.0  154.0  14.0  26.554167  72.208333
#
#       Pressure   MAXT   MINT   SPD     WDG    CLD
# 0  1006.791667  26.51  24.51  2.40  270.00  35.00
# 1  1007.333333  26.35  24.57  2.13  272.50  47.92
# 2  1009.041667  27.04  25.06  2.37  262.46  50.33
# 3  1009.250000  27.18  25.03  1.88  266.38  36.38
# 4  1007.833333  27.32  25.45  2.00  271.67  30.00

# %% [markdown]
# ### Getting values from Hardware Sensors through ThingSpeak API

# %%
from urllib.request import urlopen
import csv
url = "https://api.thingspeak.com/channels/987334/feeds/last.json?api_key=88BMJAAFH25HIF9X"

json_url = urlopen(url)
json_data = json.loads(json_url.read())
# print (json_data)
# json_data2 = json_data

vals = json_data.values()
# print (vals)
tempPM1 = (list(vals)[2])
# tempPM25 = (list(vals)[3])

tempPM25 = 45

tempPM10 = (list(vals)[4])
tempCO = (list(vals)[5])
tempTemp = (list(vals)[6])
tempHum = (list(vals)[7])
tempPress = (list(vals)[8])

# print ("\n",json_data['created_at'])
tempCreated = json_data['created_at']

import datetime
def convertDate(d):
     new_date = datetime.datetime.strptime(d,"%Y-%m-%dT%H:%M:%SZ")
     return new_date.date() # you can change the ".date()" to ".year", ".month", ".day" etc...

convertDate(tempCreated)

x = convertDate(tempCreated)
tempDate = x.strftime("%d/%m/%y")
# print(tempDate)

# %%
count = len(df)
print ("Number of records in dataset: ",count)

df.tail()
# Out:
# Number of records in dataset:  1741
#       Date_UTC  entry_id  PM1  PM25  PM10    CO       Temp   Humidity  \
# 1736  10/04/20      1736  NaN  57.0  59.0  42.0  30.697917  27.125000
# 1737  11/04/20      1737  NaN  60.0  58.0  43.0  31.407917  25.083333
# 1738  12/04/20      1738  NaN  58.0  55.0  43.0  30.998750  26.125000
# 1739  13/04/20      1739  NaN  56.0  58.0  42.0  31.213333  29.916667
# 1740  14/04/20      1740  NaN  59.0   NaN   NaN  31.462917  26.875000
#
#          Pressure   MAXT   MINT   SPD     WDG    CLD
# 1736  1011.291667  31.09  29.83  2.84  173.38  17.00
# 1737  1012.166667  31.75  30.67  2.70  197.46  12.25
# 1738  1011.166667  31.48  29.94  3.65  177.96  11.63
# 1739  1009.916667  31.86  30.03  3.20  182.71  20.88
# 1740  1010.125000  31.97  30.59  3.80  215.54   9.88

# %%
df.at[count, 'entry_id'] = count
df.at[count,'PM1'] = tempPM1
df.at[count,'PM25'] = tempPM25
df.at[count,'PM10'] = tempPM10
df.at[count,'CO'] = tempCO
df.at[count,'Temp'] = tempTemp
df.at[count,'Humidity'] = tempHum
df.at[count,'Pressure'] = tempPress
df.at[count,'Date_UTC'] = tempDate


df.tail()
# Out:
#       Date_UTC  entry_id  PM1  PM25  PM10     CO       Temp   Humidity  \
# 1737  11/04/20    1737.0  NaN  60.0  58.0  43.00  31.407917  25.083333
# 1738  12/04/20    1738.0  NaN  58.0  55.0  43.00  30.998750  26.125000
# 1739  13/04/20    1739.0  NaN  56.0  58.0  42.00  31.213333  29.916667
# 1740  14/04/20    1740.0  NaN  59.0   NaN    NaN  31.462917  26.875000
# 1741  16/05/20    1741.0  0.0  45.0   0.0  53.63  33.100000  32.000000
#
#          Pressure   MAXT   MINT   SPD     WDG    CLD
# 1737  1012.166667  31.75  30.67  2.70  197.46  12.25
# 1738  1011.166667  31.48  29.94  3.65  177.96  11.63
# 1739  1009.916667  31.86  30.03  3.20  182.71  20.88
# 1740  1010.125000  31.97  30.59  3.80  215.54   9.88
# 1741  1009.000000    NaN    NaN   NaN     NaN    NaN

# %% [markdown]
# ### Getting predicted weather conditions from OpenWeather API

# %%
import json
import requests

url = "http://api.openweathermap.org/data/2.5/forecast?id=1259229&appid=c2b23a89894073eba086b32a56afca57&units=metric"

payload = {}
headers= {}

response = requests.request("GET", url, headers=headers, data = payload)

# print(response.text.encode('utf8'))
todos = json.loads(response.text)

tempSum = 0
humiSum = 0
pressSum = 0
for i in range(8,16):
    tempSum = tempSum + (todos["list"][i]['main']['temp'])
    humiSum = humiSum + (todos["list"][i]['main']['humidity'])
    pressSum = pressSum + (todos["list"][i]['main']['pressure'])



avgTemp = tempSum / 8
avgHumi = humiSum / 8
avgPress = pressSum / 8


print("Avg Temp:", avgTemp)
print("Avg Humidity:", avgHumi)
print("Avg Pressure:", avgPress)
# Out:
# Avg Temp: 29.37375
# Avg Humidity: 39.0
# Avg Pressure: 1006.0

# %%
count = len(df)
print ("Number of records in dataset: ",count)
# Out:
# Number of records in dataset:  1742

# %%
from datetime import timedelta

def convertDate(d):
     new_date = datetime.datetime.strptime(d,"%Y-%m-%dT%H:%M:%SZ")
     return new_date.date() # you can change the ".date()" to ".year", ".month", ".day" etc...

convertDate(tempCreated)
x = convertDate(tempCreated)
x += timedelta(days=1)

tempNewDate = x.strftime("%d/%m/%y")
print(tempNewDate)
# Out:
# 17/05/20

# %%
df.at[count, 'entry_id'] = count
# df.at[count,'PM1'] = tempPM1
df.at[count,'PM25'] = 0
# df.at[count,'PM10'] = tempPM10
# df.at[count,'CO'] = tempCO
df.at[count,'Temp'] = avgTemp
df.at[count,'Humidity'] = avgHumi
df.at[count,'Pressure'] = avgPress
df.at[count,'Date_UTC'] = tempNewDate

# %%
df.tail()
# Out:
#       Date_UTC  entry_id  PM1  PM25  PM10     CO       Temp   Humidity  \
# 1738  12/04/20    1738.0  NaN  58.0  55.0  43.00  30.998750  26.125000
# 1739  13/04/20    1739.0  NaN  56.0  58.0  42.00  31.213333  29.916667
# 1740  14/04/20    1740.0  NaN  59.0   NaN    NaN  31.462917  26.875000
# 1741  16/05/20    1741.0  0.0  45.0   0.0  53.63  33.100000  32.000000
# 1742  17/05/20    1742.0  NaN   0.0   NaN    NaN  29.373750  39.000000
#
#          Pressure   MAXT   MINT   SPD     WDG    CLD
# 1738  1011.166667  31.48  29.94  3.65  177.96  11.63
# 1739  1009.916667  31.86  30.03  3.20  182.71  20.88
# 1740  1010.125000  31.97  30.59  3.80  215.54   9.88
# 1741  1009.000000    NaN    NaN   NaN     NaN    NaN
# 1742  1006.000000    NaN    NaN   NaN     NaN    NaN

# %%
df.to_csv(r"/Users/dhruv/Downloads/BE_PROJECT_CSV/PyScript/datasetRawAdded2.csv", columns = ["Date_UTC","entry_id","PM1","PM25","PM10","CO","Temp","Humidity","Pressure","MAXT","MINT","SPD","WDG","CLD"])

# %%
df['Date_UTC'] = pd.to_datetime(df['Date_UTC'], format="%d/%m/%y")
# print ("Converting Date_UTC string to datetime: ", df.dtypes)
df.index = df["Date_UTC"]

# %%
count = len(df)
print ("Number of records in dataset: ",count)
#print(df.head())
# Out:
# Number of records in dataset:  1743

# %%
df.tail()
# Out:
#              Date_UTC  entry_id  PM1  PM25  PM10     CO       Temp   Humidity  \
# Date_UTC
# 2020-04-12 2020-04-12    1738.0  NaN  58.0  55.0  43.00  30.998750  26.125000
# 2020-04-13 2020-04-13    1739.0  NaN  56.0  58.0  42.00  31.213333  29.916667
# 2020-04-14 2020-04-14    1740.0  NaN  59.0   NaN    NaN  31.462917  26.875000
# 2020-05-16 2020-05-16    1741.0  0.0  45.0   0.0  53.63  33.100000  32.000000
# 2020-05-17 2020-05-17    1742.0  NaN   0.0   NaN    NaN  29.373750  39.000000
#
#                Pressure   MAXT   MINT   SPD     WDG    CLD
# Date_UTC
# 2020-04-12  1011.166667  31.48  29.94  3.65  177.96  11.63
# 2020-04-13  1009.916667  31.86  30.03  3.20  182.71  20.88
# 2020-04-14  1010.125000  31.97  30.59  3.80  215.54   9.88
# 2020-05-16  1009.000000    NaN    NaN   NaN     NaN    NaN
# 2020-05-17  1006.000000    NaN    NaN   NaN     NaN    NaN

# %%
# df.Date_UTC.max() - df.Date_UTC.min()

#------- Since COVID-19 Lockdown -------#
# ts = pd.to_datetime('25/3/2020', format='%d/%m/%Y')
# print ("COVID-19 Lockdown since: ",ts)
# df.loc[df.Date_UTC >= ts, :].head()

# df.Date_UTC.dt.month.head()

# %%
df["day_week"] = df["Date_UTC"].dt.day_name()

# %%
# df.head(15)

# %%
df['day_week_cat'] = df.day_week.astype("category").cat.codes
# df.head(15)

# %%
df.tail()
# Out:
#              Date_UTC  entry_id  PM1  PM25  PM10     CO       Temp   Humidity  \
# Date_UTC
# 2020-04-12 2020-04-12    1738.0  NaN  58.0  55.0  43.00  30.998750  26.125000
# 2020-04-13 2020-04-13    1739.0  NaN  56.0  58.0  42.00  31.213333  29.916667
# 2020-04-14 2020-04-14    1740.0  NaN  59.0   NaN    NaN  31.462917  26.875000
# 2020-05-16 2020-05-16    1741.0  0.0  45.0   0.0  53.63  33.100000  32.000000
# 2020-05-17 2020-05-17    1742.0  NaN   0.0   NaN    NaN  29.373750  39.000000
#
#                Pressure   MAXT   MINT   SPD     WDG    CLD  day_week  \
# Date_UTC
# 2020-04-12  1011.166667  31.48  29.94  3.65  177.96  11.63    Sunday
# 2020-04-13  1009.916667  31.86  30.03  3.20  182.71  20.88    Monday
# 2020-04-14  1010.125000  31.97  30.59  3.80  215.54   9.88   Tuesday
# 2020-05-16  1009.000000    NaN    NaN   NaN     NaN    NaN  Saturday
# 2020-05-17  1006.000000    NaN    NaN   NaN     NaN    NaN    Sunday
#
#             day_week_cat
# Date_UTC
# 2020-04-12             3
# 2020-04-13             1
# 2020-04-14             5
# 2020-05-16             2
# 2020-05-17             3

# %%
df['month'] = df["Date_UTC"].dt.month
# df.head(20)

# %%
# df = df[df['PM25'] <= 250]
df.shape
# Out:
# (1743, 17)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = [16,9]

# %%
x = df['month']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Month')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Month')
plt.show()

# %%
#df = df[int(df['PM2.5']) <= 220]

x = df['day_week']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Day of Week')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Day of the Week')
plt.show()

# %%
x = df['Temp']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Temperature(C)')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Temperature(C)')
plt.show()

# %%
x = df['Humidity']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Humidity')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Humidity')
plt.show()

# %%
x = df['Pressure']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Pressure')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Pressure')
plt.show()

# %%
x = df['MAXT']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Max Temp')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Average MaxTemp')
plt.show()

# %%
x = df['MINT']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Min Temp')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Average MinTemp')
plt.show()

# %%
x = df['SPD']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Average Wind Speed')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Average Wind Speed')
plt.show()

# %%
# x = df['WDG']
# y = df['PM25']
# plt.scatter(x,y)
# plt.xlabel('Wind Direction')
# plt.ylabel('PM2.5 Level')
# plt.title('PM2.5 by Wind Degree')
# plt.show()

# %%
x = df['CLD']
y = df['PM25']
plt.scatter(x,y)
plt.xlabel('Average Cloud Cover')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Average Cloud Cover')
plt.show()

# %%
df.tail()
# Out:
#              Date_UTC  entry_id  PM1  PM25  PM10     CO       Temp   Humidity  \
# Date_UTC
# 2020-04-12 2020-04-12    1738.0  NaN  58.0  55.0  43.00  30.998750  26.125000
# 2020-04-13 2020-04-13    1739.0  NaN  56.0  58.0  42.00  31.213333  29.916667
# 2020-04-14 2020-04-14    1740.0  NaN  59.0   NaN    NaN  31.462917  26.875000
# 2020-05-16 2020-05-16    1741.0  0.0  45.0   0.0  53.63  33.100000  32.000000
# 2020-05-17 2020-05-17    1742.0  NaN   0.0   NaN    NaN  29.373750  39.000000
#
#                Pressure   MAXT   MINT   SPD     WDG    CLD  day_week  \
# Date_UTC
# 2020-04-12  1011.166667  31.48  29.94  3.65  177.96  11.63    Sunday
# 2020-04-13  1009.916667  31.86  30.03  3.20  182.71  20.88    Monday
# 2020-04-14  1010.125000  31.97  30.59  3.80  215.54   9.88   Tuesday
# 2020-05-16  1009.000000    NaN    NaN   NaN     NaN    NaN  Saturday
# 2020-05-17  1006.000000    NaN    NaN   NaN     NaN    NaN    Sunday
#
#             day_week_cat  month
# Date_UTC
# 2020-04-12             3      4
# 2020-04-13             1      4
# 2020-04-14             5      4
# 2020-05-16             2      5
# 2020-05-17             3      5

# %%
# from scipy import stats
# import numpy as np
# z = np.abs(stats.zscore(df['PM25']))
# print (z)

# %% [markdown]
# There seems to be a outlier in the dataset, which happens to occur in the month of March of some year. Thus, we further analyze this using a time_series graph in the next section, where we handle the ouliers in the dataset.

# %% [markdown]
# # Handling Outliers

# %% [markdown]
# Let's handle theoutlier points in the PM25 feature. First lets take a look at the date range from the graph above.

# %%
def time_series(start, end):
    time_series_df = df[['Date_UTC', 'PM25']][(df['Date_UTC'] >= start) & (df['Date_UTC'] <= end)]
    x = time_series_df.Date_UTC
    y = time_series_df.PM25
    plt.plot(x,y)
    plt.xlabel('Time')
    plt.ylabel('PM2.5 Value')
    plt.title('PM2.5 Time Series')
    return plt.show();

# %%
# time_series('2017','2017-05')
time_series('2015','2021')

# %% [markdown]
# There seems to be a unforeseen spike around the early stages of 2016. Let's further look into it.

# %%
time_series('2016','2016-05')
# time_series('2018','2018-05')
# time_series('2019','2019-05')
# time_series('2020','2020-05')

# %%
df.tail()
# Out:
#              Date_UTC  entry_id  PM1  PM25  PM10     CO       Temp   Humidity  \
# Date_UTC
# 2020-04-12 2020-04-12    1738.0  NaN  58.0  55.0  43.00  30.998750  26.125000
# 2020-04-13 2020-04-13    1739.0  NaN  56.0  58.0  42.00  31.213333  29.916667
# 2020-04-14 2020-04-14    1740.0  NaN  59.0   NaN    NaN  31.462917  26.875000
# 2020-05-16 2020-05-16    1741.0  0.0  45.0   0.0  53.63  33.100000  32.000000
# 2020-05-17 2020-05-17    1742.0  NaN   0.0   NaN    NaN  29.373750  39.000000
#
#                Pressure   MAXT   MINT   SPD     WDG    CLD  day_week  \
# Date_UTC
# 2020-04-12  1011.166667  31.48  29.94  3.65  177.96  11.63    Sunday
# 2020-04-13  1009.916667  31.86  30.03  3.20  182.71  20.88    Monday
# 2020-04-14  1010.125000  31.97  30.59  3.80  215.54   9.88   Tuesday
# 2020-05-16  1009.000000    NaN    NaN   NaN     NaN    NaN  Saturday
# 2020-05-17  1006.000000    NaN    NaN   NaN     NaN    NaN    Sunday
#
#             day_week_cat  month
# Date_UTC
# 2020-04-12             3      4
# 2020-04-13             1      4
# 2020-04-14             5      4
# 2020-05-16             2      5
# 2020-05-17             3      5

# %% [markdown]
# After exploring the spikes throughout the dataset, we see that there is only one which exceeds 200. We know from external reports that pollution is actually getting worse year over year. This leads to the conclusion that these points are possible in error and should be removed.

# %%
df = df[df['PM25'] <= 220]
time_series ('2016', '2016-05')

# %%
time_series('2015', '2021')

# %%
df.isnull().any()
# df.dropna()
# Out:
# Date_UTC        False
# entry_id        False
# PM1              True
# PM25            False
# PM10             True
# CO               True
# Temp            False
# Humidity        False
# Pressure        False
# MAXT             True
# MINT             True
# SPD              True
# WDG              True
# CLD              True
# day_week        False
# day_week_cat    False
# month           False
# dtype: bool

# %%
df.describe()
# Out:
#           entry_id  PM1         PM25         PM10           CO         Temp  \
# count  1691.000000  1.0  1691.000000  1662.000000  1413.000000  1691.000000
# mean    883.126552  0.0    57.905381    61.088448    41.944536    24.615936
# std     500.083465  NaN    27.491719    28.488789    53.818726     3.044764
# min       0.000000  0.0     0.000000     0.000000     2.000000    15.976250
# 25%     453.500000  0.0    35.000000    36.000000    25.000000    22.866250
# 50%     889.000000  0.0    56.000000    63.000000    38.000000    24.263750
# 75%    1316.500000  0.0    76.000000    82.000000    51.000000    26.395000
# max    1742.000000  0.0   183.000000   264.000000  1462.000000    33.925417
#
#           Humidity     Pressure         MAXT         MINT          SPD  \
# count  1691.000000  1691.000000  1689.000000  1689.000000  1689.000000
# mean     64.552702  1010.982203    25.676211    23.061533     1.704831
# std      17.162752     3.787650     3.043216     2.782552     0.537377
# min      20.750000  1000.833333    17.400000    14.490000     0.750000
# 25%      52.062500  1008.166667    23.770000    21.140000     1.330000
# 50%      65.541667  1011.166667    25.130000    23.160000     1.610000
# 75%      78.979167  1013.875000    27.450000    24.820000     1.960000
# max      96.833333  1020.458333    35.420000    30.670000     4.930000
#
#                WDG          CLD  day_week_cat        month
# count  1689.000000  1689.000000   1691.000000  1691.000000
# mean    206.034239    22.357845      3.001183     6.535186
# std      73.035171    14.680312      2.011211     3.517215
# min      42.500000     0.000000      0.000000     1.000000
# 25%     143.330000     8.880000      1.000000     3.000000
# 50%     234.790000    23.670000      3.000000     7.000000
# 75%     269.920000    35.000000      5.000000    10.000000
# max     322.170000    78.250000      6.000000    12.000000

# %%
df.tail()
# Out:
#              Date_UTC  entry_id  PM1  PM25  PM10     CO       Temp   Humidity  \
# Date_UTC
# 2020-04-12 2020-04-12    1738.0  NaN  58.0  55.0  43.00  30.998750  26.125000
# 2020-04-13 2020-04-13    1739.0  NaN  56.0  58.0  42.00  31.213333  29.916667
# 2020-04-14 2020-04-14    1740.0  NaN  59.0   NaN    NaN  31.462917  26.875000
# 2020-05-16 2020-05-16    1741.0  0.0  45.0   0.0  53.63  33.100000  32.000000
# 2020-05-17 2020-05-17    1742.0  NaN   0.0   NaN    NaN  29.373750  39.000000
#
#                Pressure   MAXT   MINT   SPD     WDG    CLD  day_week  \
# Date_UTC
# 2020-04-12  1011.166667  31.48  29.94  3.65  177.96  11.63    Sunday
# 2020-04-13  1009.916667  31.86  30.03  3.20  182.71  20.88    Monday
# 2020-04-14  1010.125000  31.97  30.59  3.80  215.54   9.88   Tuesday
# 2020-05-16  1009.000000    NaN    NaN   NaN     NaN    NaN  Saturday
# 2020-05-17  1006.000000    NaN    NaN   NaN     NaN    NaN    Sunday
#
#             day_week_cat  month
# Date_UTC
# 2020-04-12             3      4
# 2020-04-13             1      4
# 2020-04-14             5      4
# 2020-05-16             2      5
# 2020-05-17             3      5

# %%
# def time_series(start, end):
#     time_series_df = df[['Date_UTC', 'Pressure']][(df['Date_UTC'] >= start) & (df['Date_UTC'] <= end)]
#     x = time_series_df.Date_UTC
#     y = time_series_df.Pressure
#     plt.plot(x,y)
#     plt.xlabel('Time')
#     plt.ylabel('Pressure')
#     plt.title('Pressure Time Series')
#     return plt.show();

# time_series('2015','2021')

# %%
# def time_series(start, end):
#     time_series_df = df[['Date_UTC', 'SPD']][(df['Date_UTC'] >= start) & (df['Date_UTC'] <= end)]
#     x = time_series_df.Date_UTC
#     y = time_series_df.SPD
#     plt.plot(x,y)
#     plt.xlabel('Time')
#     plt.ylabel('SPD')
#     plt.title('SPD Time Series')
#     return plt.show();

# time_series('2015','2021')

# %%
# def time_series(start, end):
#     time_series_df = df[['Date_UTC', 'Temp']][(df['Date_UTC'] >= start) & (df['Date_UTC'] <= end)]
#     x = time_series_df.Date_UTC
#     y = time_series_df.Temp
#     plt.plot(x,y)
#     plt.xlabel('Time')
#     plt.ylabel('Temp')
#     plt.title('Temp Time Series')
#     return plt.show();

# time_series('2015','2021')

# %%
# def time_series(start, end):
#     time_series_df = df[['Date_UTC', 'CLD']][(df['Date_UTC'] >= start) & (df['Date_UTC'] <= end)]
#     x = time_series_df.Date_UTC
#     y = time_series_df.CLD
#     plt.plot(x,y)
#     plt.xlabel('Time')
#     plt.ylabel('CLD')
#     plt.title('CLD Time Series')
#     return plt.show();

# time_series('2015','2021')

# %%
# def time_series(start, end):
#     time_series_df = df[['Date_UTC', 'Humidity']][(df['Date_UTC'] >= start) & (df['Date_UTC'] <= end)]
#     x = time_series_df.Date_UTC
#     y = time_series_df.Humidity
#     plt.plot(x,y)
#     plt.xlabel('Time')
#     plt.ylabel('Humidity')
#     plt.title('Humidity Time Series')
#     return plt.show();

# time_series('2015','2021')

# %%
# def time_series(start, end):
#     time_series_df = df[['Date_UTC', 'WDG']][(df['Date_UTC'] >= start) & (df['Date_UTC'] <= end)]
#     x = time_series_df.Date_UTC
#     y = time_series_df.WDG
#     plt.plot(x,y)
#     plt.xlabel('Time')
#     plt.ylabel('WDG')
#     plt.title('WDG Time Series')
#     return plt.show();

# time_series('2015','2021')

# %%
# time_series('2015','2021')

# %% [markdown]
# # Random Analysis Code

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
load = df[['PM25', 'month']].groupby(['month']).mean()

# %%
load.plot(kind='bar')

# %% [markdown]
# # Dropping Attributes

# %%
df = df.drop(['Date_UTC','entry_id','PM1','day_week','PM10','CO','WDG'], axis=1)

df.shape
# df.dropna()
# df.isnull.values().any()

df.shape
# Out:
# (1691, 10)

# %%
df = df.drop(['MAXT','MINT','SPD','CLD'], axis=1)
df.shape
# Out:
# (1691, 6)

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
df.dropna(thresh=1)
df.shape
df.dtypes
# df.CO.isnull().any()
# Out:
# PM25            float64
# Temp            float64
# Humidity        float64
# Pressure        float64
# day_week_cat       int8
# month             int64
# dtype: object

# %%
df.corr()
# Out:
#                   PM25      Temp  Humidity  Pressure  day_week_cat     month
# PM25          1.000000 -0.172483 -0.433468  0.569809     -0.019250 -0.091549
# Temp         -0.172483  1.000000 -0.383377 -0.474113      0.002753 -0.200323
# Humidity     -0.433468 -0.383377  1.000000 -0.328107     -0.001115  0.566724
# Pressure      0.569809 -0.474113 -0.328107  1.000000      0.001992 -0.040160
# day_week_cat -0.019250  0.002753 -0.001115  0.001992      1.000000 -0.004523
# month        -0.091549 -0.200323  0.566724 -0.040160     -0.004523  1.000000

# %%
df.tail()
# Out:
#             PM25       Temp   Humidity     Pressure  day_week_cat  month
# Date_UTC
# 2020-04-12  58.0  30.998750  26.125000  1011.166667             3      4
# 2020-04-13  56.0  31.213333  29.916667  1009.916667             1      4
# 2020-04-14  59.0  31.462917  26.875000  1010.125000             5      4
# 2020-05-16  45.0  33.100000  32.000000  1009.000000             2      5
# 2020-05-17   0.0  29.373750  39.000000  1006.000000             3      5

# %% [markdown]
# # Testing previous periods

# %%
df['PM25_1'] = df.PM25.shift(periods=1)
df['Temp_1'] = df.Temp.shift(periods=1)
df['Pressure_1'] = df.Pressure.shift(periods=1)
df['Humidity_1'] = df.Humidity.shift(periods=1)

df['PM25_2'] = df.PM25.shift(periods=2)
df['Temp_2'] = df.Temp.shift(periods=2)
df['Pressure_2'] = df.Pressure.shift(periods=2)
df['Humidity_2'] = df.Humidity.shift(periods=2)

df['PM25_3'] = df.PM25.shift(periods=3)
df['Temp_3'] = df.Temp.shift(periods=3)
df['Pressure_3'] = df.Pressure.shift(periods=3)
df['Humidity_3'] = df.Humidity.shift(periods=3)

# %%
# df.head(20)

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
df.dropna(thresh=1)
df.shape
df.dtypes
# df.CO.isnull().any()
# Out:
# PM25            float64
# Temp            float64
# Humidity        float64
# Pressure        float64
# day_week_cat       int8
# month             int64
# PM25_1          float64
# Temp_1          float64
# Pressure_1      float64
# Humidity_1      float64
# PM25_2          float64
# Temp_2          float64
# Pressure_2      float64
# Humidity_2      float64
# PM25_3          float64
# Temp_3          float64
# Pressure_3      float64
# Humidity_3      float64
# dtype: object

# %%
df.corr()
# Out:
#                   PM25      Temp  Humidity  Pressure  day_week_cat     month  \
# PM25          1.000000 -0.172483 -0.433468  0.569809     -0.019250 -0.091549
# Temp         -0.172483  1.000000 -0.383377 -0.474113      0.002753 -0.200323
# Humidity     -0.433468 -0.383377  1.000000 -0.328107     -0.001115  0.566724
# Pressure      0.569809 -0.474113 -0.328107  1.000000      0.001992 -0.040160
# day_week_cat -0.019250  0.002753 -0.001115  0.001992      1.000000 -0.004523
# month        -0.091549 -0.200323  0.566724 -0.040160     -0.004523  1.000000
# PM25_1        0.906347 -0.172742 -0.430874  0.554902     -0.019748 -0.100856
# Temp_1       -0.181732  0.963307 -0.357760 -0.479834      0.009958 -0.183439
# Pressure_1    0.581163 -0.455504 -0.350623  0.965012     -0.003611 -0.053818
# Humidity_1   -0.432156 -0.383406  0.956863 -0.314134     -0.001676  0.565853
# PM25_2        0.781747 -0.178082 -0.426760  0.542891     -0.004222 -0.111268
# Temp_2       -0.202153  0.916913 -0.339761 -0.486612      0.007734 -0.166289
# Pressure_2    0.586700 -0.443358 -0.364133  0.914249      0.003151 -0.068073
# Humidity_2   -0.423752 -0.387962  0.919895 -0.300222      0.004938  0.567050
# PM25_3        0.709249 -0.185510 -0.424096  0.531015      0.008433 -0.119673
# Temp_3       -0.220798  0.880005 -0.326682 -0.495057     -0.000379 -0.146453
# Pressure_3    0.586546 -0.434651 -0.373947  0.881268      0.013022 -0.081545
# Humidity_3   -0.410038 -0.392883  0.892731 -0.285948      0.007885  0.567127
#
#                 PM25_1    Temp_1  Pressure_1  Humidity_1    PM25_2    Temp_2  \
# PM25          0.906347 -0.181732    0.581163   -0.432156  0.781747 -0.202153
# Temp         -0.172742  0.963307   -0.455504   -0.383406 -0.178082  0.916913
# Humidity     -0.430874 -0.357760   -0.350623    0.956863 -0.426760 -0.339761
# Pressure      0.554902 -0.479834    0.965012   -0.314134  0.542891 -0.486612
# day_week_cat -0.019748  0.009958   -0.003611   -0.001676 -0.004222  0.007734
# month        -0.100856 -0.183439   -0.053818    0.565853 -0.111268 -0.166289
# PM25_1        1.000000 -0.170883    0.569207   -0.436184  0.907011 -0.178900
# Temp_1       -0.170883  1.000000   -0.473481   -0.382527 -0.172442  0.963643
# Pressure_1    0.569207 -0.473481    1.000000   -0.329651  0.554856 -0.479010
# Humidity_1   -0.436184 -0.382527   -0.329651    1.000000 -0.431601 -0.356356
# PM25_2        0.907011 -0.172442    0.554856   -0.431601  1.000000 -0.170509
# Temp_2       -0.178900  0.963643   -0.479010   -0.356356 -0.170509  1.000000
# Pressure_2    0.581320 -0.455385    0.965177   -0.351345  0.569145 -0.473746
# Humidity_2   -0.435561 -0.382333   -0.316114    0.956839 -0.437210 -0.380674
# PM25_3        0.782825 -0.178247    0.543201   -0.427007  0.907082 -0.172904
# Temp_3       -0.199901  0.916871   -0.485834   -0.338504 -0.178551  0.963588
# Pressure_3    0.587197 -0.443475    0.914556   -0.364579  0.581304 -0.456068
# Humidity_3   -0.427673 -0.386759   -0.302529    0.919878 -0.436832 -0.380119
#
#               Pressure_2  Humidity_2    PM25_3    Temp_3  Pressure_3  \
# PM25            0.586700   -0.423752  0.709249 -0.220798    0.586546
# Temp           -0.443358   -0.387962 -0.185510  0.880005   -0.434651
# Humidity       -0.364133    0.919895 -0.424096 -0.326682   -0.373947
# Pressure        0.914249   -0.300222  0.531015 -0.495057    0.881268
# day_week_cat    0.003151    0.004938  0.008433 -0.000379    0.013022
# month          -0.068073    0.567050 -0.119673 -0.146453   -0.081545
# PM25_1          0.581320   -0.435561  0.782825 -0.199901    0.587197
# Temp_1         -0.455385   -0.382333 -0.178247  0.916871   -0.443475
# Pressure_1      0.965177   -0.316114  0.543201 -0.485834    0.914556
# Humidity_1     -0.351345    0.956839 -0.427007 -0.338504   -0.364579
# PM25_2          0.569145   -0.437210  0.907082 -0.178551    0.581304
# Temp_2         -0.473746   -0.380674 -0.172904  0.963588   -0.456068
# Pressure_2      1.000000   -0.330621  0.554914 -0.479071    0.965200
# Humidity_2     -0.330621    1.000000 -0.432020 -0.354732   -0.351982
# PM25_3          0.554914   -0.432020  1.000000 -0.170818    0.569159
# Temp_3         -0.479071   -0.354732 -0.170818  1.000000   -0.474165
# Pressure_3      0.965200   -0.351982  0.569159 -0.474165    1.000000
# Humidity_3     -0.317279    0.956758 -0.437788 -0.378847   -0.331398
#
#               Humidity_3
# PM25           -0.410038
# Temp           -0.392883
# Humidity        0.892731
# Pressure       -0.285948
# day_week_cat    0.007885
# month           0.567127
# PM25_1         -0.427673
# Temp_1         -0.386759
# Pressure_1     -0.302529
# Humidity_1      0.919878
# PM25_2         -0.436832
# Temp_2         -0.380119
# Pressure_2     -0.317279
# Humidity_2      0.956758
# PM25_3         -0.437788
# Temp_3         -0.378847
# Pressure_3     -0.331398
# Humidity_3      1.000000

# %% [markdown]
# # Visualizing Features

# %%
# import seaborn as sns
# g = sns.PairGrid(df, vars=["month", "PM25", "SPD", "Temp"], dropna=True)
# g.map_diag(plt.hist)
# g.map_offdiag(plt.scatter);

# %%
# g = sns.FacetGrid(df, col='month', col_wrap=4)
# g.map(sns.distplot, "PM25")
# plt.show()

# %%
# g = sns.FacetGrid(df, col='month', col_wrap=4)
# g.map(plt.scatter, "Pressure","PM25")
# plt.show()

# %%
# g = sns.FacetGrid(df, col='month', col_wrap=4)
# g.map(plt.scatter, "Temp","PM25")
# plt.show()

# %%
# g = sns.FacetGrid(df, col='month', col_wrap=4)
# g.map(plt.scatter, "Temp","SPD")
# plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df['month_sin'] = np.sin((df.month-1)*(2.*np.pi/12))
df['month_cos'] = np.cos((df.month-1)*(2.*np.pi/12))

df.plot.scatter('month_sin','month_cos').set_aspect('equal')
plt.show()

df = df.drop(['month'], axis=1)

# %%
df = df.iloc[3:]
df.head(10)
# Out:
#             PM25       Temp   Humidity     Pressure  day_week_cat  PM25_1  \
# Date_UTC
# 2015-07-13  57.0  26.346250  72.541667  1009.250000             1    59.0
# 2015-07-14  58.0  26.554167  72.208333  1007.833333             5    57.0
# 2015-07-15  58.0  25.656667  73.708333  1006.583333             6    58.0
# 2015-07-16  56.0  25.328333  78.125000  1004.708333             4    58.0
# 2015-07-17  59.0  25.669583  76.708333  1005.125000             0    56.0
# 2015-07-18  67.0  25.022083  81.333333  1006.875000             2    59.0
# 2015-07-19  68.0  24.573750  83.416667  1007.416667             3    67.0
# 2015-07-20  51.0  24.333333  83.583333  1006.291667             1    68.0
# 2015-07-21  48.0  23.695000  92.000000  1006.750000             5    51.0
# 2015-07-22  40.0  24.055000  89.333333  1006.875000             6    48.0
#
#                Temp_1   Pressure_1  Humidity_1  PM25_2     Temp_2  \
# Date_UTC
# 2015-07-13  26.253333  1009.041667   71.291667    48.0  25.710833
# 2015-07-14  26.346250  1009.250000   72.541667    59.0  26.253333
# 2015-07-15  26.554167  1007.833333   72.208333    57.0  26.346250
# 2015-07-16  25.656667  1006.583333   73.708333    58.0  26.554167
# 2015-07-17  25.328333  1004.708333   78.125000    58.0  25.656667
# 2015-07-18  25.669583  1005.125000   76.708333    56.0  25.328333
# 2015-07-19  25.022083  1006.875000   81.333333    59.0  25.669583
# 2015-07-20  24.573750  1007.416667   83.416667    67.0  25.022083
# 2015-07-21  24.333333  1006.291667   83.583333    68.0  24.573750
# 2015-07-22  23.695000  1006.750000   92.000000    51.0  24.333333
#
#              Pressure_2  Humidity_2  PM25_3     Temp_3   Pressure_3  \
# Date_UTC
# 2015-07-13  1007.333333   74.291667    45.0  25.585000  1006.791667
# 2015-07-14  1009.041667   71.291667    48.0  25.710833  1007.333333
# 2015-07-15  1009.250000   72.541667    59.0  26.253333  1009.041667
# 2015-07-16  1007.833333   72.208333    57.0  26.346250  1009.250000
# 2015-07-17  1006.583333   73.708333    58.0  26.554167  1007.833333
# 2015-07-18  1004.708333   78.125000    58.0  25.656667  1006.583333
# 2015-07-19  1005.125000   76.708333    56.0  25.328333  1004.708333
# 2015-07-20  1006.875000   81.333333    59.0  25.669583  1005.125000
# 2015-07-21  1007.416667   83.416667    67.0  25.022083  1006.875000
# 2015-07-22  1006.291667   83.583333    68.0  24.573750  1007.416667
#
#             Humidity_3     month_sin  month_cos
# Date_UTC
# 2015-07-13   76.833333  1.224647e-16       -1.0
# 2015-07-14   74.291667  1.224647e-16       -1.0
# 2015-07-15   71.291667  1.224647e-16       -1.0
# 2015-07-16   72.541667  1.224647e-16       -1.0
# 2015-07-17   72.208333  1.224647e-16       -1.0
# 2015-07-18   73.708333  1.224647e-16       -1.0
# 2015-07-19   78.125000  1.224647e-16       -1.0
# 2015-07-20   76.708333  1.224647e-16       -1.0
# 2015-07-21   81.333333  1.224647e-16       -1.0
# 2015-07-22   83.416667  1.224647e-16       -1.0

# %% [markdown]
# # Create Final Dataset

# %%
df.to_csv(r"/Users/dhruv/Downloads/BE_PROJECT_CSV/PyScript/clairityCleanedAdded2.csv")

# %%
df.tail()
# Out:
#             PM25       Temp   Humidity     Pressure  day_week_cat  PM25_1  \
# Date_UTC
# 2020-04-12  58.0  30.998750  26.125000  1011.166667             3    60.0
# 2020-04-13  56.0  31.213333  29.916667  1009.916667             1    58.0
# 2020-04-14  59.0  31.462917  26.875000  1010.125000             5    56.0
# 2020-05-16  45.0  33.100000  32.000000  1009.000000             2    59.0
# 2020-05-17   0.0  29.373750  39.000000  1006.000000             3    45.0
#
#                Temp_1   Pressure_1  Humidity_1  PM25_2     Temp_2  \
# Date_UTC
# 2020-04-12  31.407917  1012.166667   25.083333    57.0  30.697917
# 2020-04-13  30.998750  1011.166667   26.125000    60.0  31.407917
# 2020-04-14  31.213333  1009.916667   29.916667    58.0  30.998750
# 2020-05-16  31.462917  1010.125000   26.875000    56.0  31.213333
# 2020-05-17  33.100000  1009.000000   32.000000    59.0  31.462917
#
#              Pressure_2  Humidity_2  PM25_3     Temp_3   Pressure_3  \
# Date_UTC
# 2020-04-12  1011.291667   27.125000    57.0  28.472083  1011.250000
# 2020-04-13  1012.166667   25.083333    57.0  30.697917  1011.291667
# 2020-04-14  1011.166667   26.125000    60.0  31.407917  1012.166667
# 2020-05-16  1009.916667   29.916667    58.0  30.998750  1011.166667
# 2020-05-17  1010.125000   26.875000    56.0  31.213333  1009.916667
#
#             Humidity_3  month_sin     month_cos
# Date_UTC
# 2020-04-12   32.291667   1.000000  6.123234e-17
# 2020-04-13   27.125000   1.000000  6.123234e-17
# 2020-04-14   25.083333   1.000000  6.123234e-17
# 2020-05-16   26.125000   0.866025 -5.000000e-01
# 2020-05-17   29.916667   0.866025 -5.000000e-01

# %% [markdown]
# # Split into Training and Test Data

# %% [markdown]
# Cross validation is always desired when training machine learning models to be able to trust the generality of the model created. We will split our data into training and test data using Scikit learn's built in tools. Also for scikit learn we need to separate our dataset into inputs and the feature being predicted (or X's and y's).

# %%
y = df['PM25']
y = y[:-1]

# %%
X = df.drop(['PM25'], axis = 1)
# X.shape

# %%
X = X[:-1]
# X.shape
X.tail(2)
# Out:
#                  Temp  Humidity  Pressure  day_week_cat  PM25_1     Temp_1  \
# Date_UTC
# 2020-04-14  31.462917    26.875  1010.125             5    56.0  31.213333
# 2020-05-16  33.100000    32.000  1009.000             2    59.0  31.462917
#
#              Pressure_1  Humidity_1  PM25_2     Temp_2   Pressure_2  \
# Date_UTC
# 2020-04-14  1009.916667   29.916667    58.0  30.998750  1011.166667
# 2020-05-16  1010.125000   26.875000    56.0  31.213333  1009.916667
#
#             Humidity_2  PM25_3     Temp_3   Pressure_3  Humidity_3  month_sin  \
# Date_UTC
# 2020-04-14   26.125000    60.0  31.407917  1012.166667   25.083333   1.000000
# 2020-05-16   29.916667    58.0  30.998750  1011.166667   26.125000   0.866025
#
#                month_cos
# Date_UTC
# 2020-04-14  6.123234e-17
# 2020-05-16 -5.000000e-01

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=1234)

# %%
X_train.shape, y_train.shape
# Out:
# ((1180, 18), (1180,))

# %%
X_test.shape, y_test.shape
# Out:
# ((507, 18), (507,))

# %%
X.columns
# Out:
# Index(['Temp', 'Humidity', 'Pressure', 'day_week_cat', 'PM25_1', 'Temp_1',
#        'Pressure_1', 'Humidity_1', 'PM25_2', 'Temp_2', 'Pressure_2',
#        'Humidity_2', 'PM25_3', 'Temp_3', 'Pressure_3', 'Humidity_3',
#        'month_sin', 'month_cos'],
#       dtype='object')

# %% [markdown]
# # Implementing SMOTE

# %%
# from imblearn.over_sampling import SMOTE

# oversampler=SMOTE(random_state=1234, ratio = 1.0, k_neighbors=3)
# os_X,os_y=oversampler.fit_sample(np.asarray(X_train),np.asarray(y_train))

# %%
# # verify new data set is balanced
# len(os_y[os_y==1])

# %% [markdown]
# # Trying SMO-GN

# %%
# import smogn
# # import pandas as pd
# # import seaborn as sns

# %%
# df_smogn = smogn.smoter(
    
#     data = df,  ## pandas dataframe
#     y = "PM25"  ## string ('header name')
# )

# %%
# df.shape

# %%
# df_smogn.shape

# %%
plt.style.use('ggplot')
# plt.axis('square')
plt.rcParams["figure.figsize"] = [12,12]

# %% [markdown]
# # Implementing ML Algorithms

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create linear regression object
regr = LinearRegression()

# %%
# Train the model using the training sets
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Make predictions using the testing set
lin_pred = regr.predict(X_test)

# %%
linear_regression_score = regr.score(X_test, y_test)
linear_regression_score
# Out:
# 0.8338890928891082

# %%
from math import sqrt
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, lin_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, lin_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, lin_pred))
# Out:
# Coefficients:
#  [ 0.53075672 -0.08859454  0.41754452  0.09796844  1.12935822  1.02753734
#   0.10285923 -0.01597224 -0.51718545 -1.80030743  0.31105292 -0.1146499
#   0.21648589  0.37371546 -0.67645252  0.17767438 -0.27924021  3.26803204]
# Root mean squared error: 11.37
# Mean absolute error: 7.38
# R-squared: 0.83

# %%
plt.scatter(y_test, lin_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Linear Regression Predicted vs Actual')
plt.show()

# %% [markdown]
# ## Neural Network Regression

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create MLPRegressor object
mlp = MLPRegressor(hidden_layer_sizes = 300, random_state = 1234)

# Train the model using the training sets
mlp.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=300, learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=200,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=1234, shuffle=True, solver='adam',
#              tol=0.0001, validation_fraction=0.1, verbose=False,
#              warm_start=False)

# %%
# Score the model
neural_network_regression_score = mlp.score(X_test, y_test)
neural_network_regression_score
# Out:
# 0.8358281302572241

# %%
# Make predictions using the testing set
nnr_pred = mlp.predict(X_test)

# %%
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, nnr_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, nnr_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, nnr_pred))
# Out:
# Root mean squared error: 11.30
# Mean absolute error: 7.63
# R-squared: 0.84

# %%
plt.scatter(y_test, nnr_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Neural Network Regression Predicted vs Actual')
plt.show()

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

lasso = Lasso()

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
# Score the model
lasso_score = lasso.score(X_test, y_test)
lasso_score
# Out:
# 0.8370231703509111

# %%
# Make predictions using the testing set
lasso_pred = lasso.predict(X_test)

# %%
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, lasso_pred)))
# Out:
# Root mean squared error: 11.26

# %%
plt.scatter(y_test, lasso_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Lasso Predicted vs Actual')
plt.show()

# %% [markdown]
# ## ElasticNet Regression

# %%
from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet()

# %%
elasticnet.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
elasticnet_score = elasticnet.score(X_test, y_test)
elasticnet_score
# Out:
# 0.837153968166798

# %%
elasticnet_pred = elasticnet.predict(X_test)

# %%
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, elasticnet_pred)))
# Out:
# Root mean squared error: 11.26

# %%
plt.scatter(y_test, elasticnet_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('ElasticNet Predicted vs Actual')
plt.show()

# %% [markdown]
# ## Decision Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# Create Random Forrest Regressor object
regr_rf = RandomForestRegressor(n_estimators=50, random_state=1)

# %%
# Train the model using the training sets
regr_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False)

# %%
# Score the model
decision_forest_score = regr_rf.score(X_test, y_test)
decision_forest_score
# Out:
# 0.8388301899743635

# %%
# Make predictions using the testing set
regr_rf_pred = regr_rf.predict(X_test)

# %%
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, regr_rf_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, regr_rf_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, regr_rf_pred))
# Out:
# Root mean squared error: 11.20
# Mean absolute error: 7.61
# R-squared: 0.84

# %%
X.columns
# Out:
# Index(['Temp', 'Humidity', 'Pressure', 'day_week_cat', 'PM25_1', 'Temp_1',
#        'Pressure_1', 'Humidity_1', 'PM25_2', 'Temp_2', 'Pressure_2',
#        'Humidity_2', 'PM25_3', 'Temp_3', 'Pressure_3', 'Humidity_3',
#        'month_sin', 'month_cos'],
#       dtype='object')

# %%
features = X.columns
importances = regr_rf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), features[indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
plt.scatter(y_test, regr_rf_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Decision Forest Predicted vs Actual')
plt.show()

# %% [markdown]
# ## Extra Trees Regression

# %%
from sklearn.ensemble import ExtraTreesRegressor

extra_tree = ExtraTreesRegressor(n_estimators=85, random_state=12345678)

# %%
extra_tree.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=85, n_jobs=None, oob_score=False,
#                     random_state=12345678, verbose=0, warm_start=False)

# %%
extratree_score = extra_tree.score(X_test, y_test)
extratree_score
# Out:
# 0.8430444620549258

# %%
extratree_pred = extra_tree.predict(X_test)

# %%
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, extratree_pred)))
# Out:
# Root mean squared error: 11.05

# %%
features = X.columns
importances = extra_tree.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), features[indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
plt.scatter(y_test, extratree_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Extra Trees Predicted vs Actual')
plt.show()

# %%
# y = df['PM25']
# X = df.drop(df['PM25'], axis =1)
# print ('Predicted PM25: ',extra_tree.predict(X))

# %% [markdown]
# ## Decision Tree + AdaBoost

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create Decision Tree Regressor object
tree_1 = DecisionTreeRegressor()

tree_2 = AdaBoostRegressor(DecisionTreeRegressor(), n_estimators=60, learning_rate=.1)

# %%
# Train the model using the training sets
tree_1.fit(X_train, y_train)
tree_2.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(ccp_alpha=0.0,
#                                                        criterion='mse',
#                                                        max_depth=None,
#                                                        max_features=None,
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        presort='deprecated',
#                                                        random_state=None,
#                                                        splitter='best'),
#                   learning_rate=0.1, loss='linear', n_estimators=60,
#                   random_state=None)

# %%
# Score the decision tree model
tree_1.score(X_test, y_test)
# Out:
# 0.6897450676611904

# %%
# Score the boosted decision tree model
boosted_tree_score = tree_2.score(X_test, y_test)
boosted_tree_score
# Out:
# 0.8238215850579255

# %%
# Make predictions using the testing set
tree_1_pred = tree_1.predict(X_test)
tree_2_pred = tree_2.predict(X_test)

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, tree_2_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, tree_2_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, tree_2_pred))
# Out:
# Coefficients:
#  [ 0.53075672 -0.08859454  0.41754452  0.09796844  1.12935822  1.02753734
#   0.10285923 -0.01597224 -0.51718545 -1.80030743  0.31105292 -0.1146499
#   0.21648589  0.37371546 -0.67645252  0.17767438 -0.27924021  3.26803204]
# Root mean squared error: 11.71
# Mean absolute error: 7.71
# R-squared: 0.82

# %%
features = X.columns
importances = tree_2.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), features[indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
plt.scatter(y_test, tree_1_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Decision Tree Predicted vs Actual')
plt.show()

# %%
plt.scatter(y_test, tree_2_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Boosted Decision Tree Predicted vs Actual')
plt.show()

# %% [markdown]
# ## XGBoost

# %%
# import os
# os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
from xgboost.sklearn import XGBRegressor

#Fitting XGB regressor 
xboost = XGBRegressor(n_estimators=40)

# %%
xboost.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=40, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %%
xgb_score = xboost.score(X_test, y_test)
xgb_score
# Out:
# 0.823983063761221

# %%
#Predict 
xboost_pred = xboost.predict(X_test)

# %%
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, xboost_pred)))
# Out:
# Root mean squared error: 11.70

# %%
plt.scatter(y_test, xboost_pred)
plt.axis('square')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('XGBoost Predicted vs Actual')
plt.show()

# %% [markdown]
# # Evaluation of Models

# %%
print("Scores:")
print("Linear regression score: ", linear_regression_score)
print("Neural network regression score: ", neural_network_regression_score)
print("Lasso regression score: ", lasso_score)
print("ElasticNet regression score: ", elasticnet_score)
print("Decision forest score: ", decision_forest_score)
print("Extra Trees score: ", extratree_score)
print("Boosted decision tree score: ", boosted_tree_score)
print("XGBoost score:", xgb_score)
print("\n")
print("RMSE:")
print("Linear regression RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, lin_pred)))
print("Neural network RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, nnr_pred)))
print("Lasso RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, lasso_pred)))
print("ElasticNet RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, elasticnet_pred)))
print("Decision forest RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, regr_rf_pred)))
print("Extra Trees RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, extratree_pred)))
print("Boosted decision tree RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, tree_2_pred)))
print("XGBoost RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, xboost_pred)))
# Out:
# Scores:
# Linear regression score:  0.8338890928891082
# Neural network regression score:  0.8358281302572241
# Lasso regression score:  0.8370231703509111
# ElasticNet regression score:  0.837153968166798
# Decision forest score:  0.8388301899743635
# Extra Trees score:  0.8430444620549258
# Boosted decision tree score:  0.8238215850579255
# XGBoost score: 0.823983063761221
#
#
# RMSE:
# Linear regression RMSE: 11.37
# Neural network RMSE: 11.30
# Lasso RMSE: 11.26
# ElasticNet RMSE: 11.26
# Decision forest RMSE: 11.20
# Extra Trees RMSE: 11.05
# Boosted decision tree RMSE: 11.71
# XGBoost RMSE: 11.70

# %%
df.tail()
# Out:
#             PM25       Temp   Humidity     Pressure  day_week_cat  PM25_1  \
# Date_UTC
# 2020-04-12  58.0  30.998750  26.125000  1011.166667             3    60.0
# 2020-04-13  56.0  31.213333  29.916667  1009.916667             1    58.0
# 2020-04-14  59.0  31.462917  26.875000  1010.125000             5    56.0
# 2020-05-16  45.0  33.100000  32.000000  1009.000000             2    59.0
# 2020-05-17   0.0  29.373750  39.000000  1006.000000             3    45.0
#
#                Temp_1   Pressure_1  Humidity_1  PM25_2     Temp_2  \
# Date_UTC
# 2020-04-12  31.407917  1012.166667   25.083333    57.0  30.697917
# 2020-04-13  30.998750  1011.166667   26.125000    60.0  31.407917
# 2020-04-14  31.213333  1009.916667   29.916667    58.0  30.998750
# 2020-05-16  31.462917  1010.125000   26.875000    56.0  31.213333
# 2020-05-17  33.100000  1009.000000   32.000000    59.0  31.462917
#
#              Pressure_2  Humidity_2  PM25_3     Temp_3   Pressure_3  \
# Date_UTC
# 2020-04-12  1011.291667   27.125000    57.0  28.472083  1011.250000
# 2020-04-13  1012.166667   25.083333    57.0  30.697917  1011.291667
# 2020-04-14  1011.166667   26.125000    60.0  31.407917  1012.166667
# 2020-05-16  1009.916667   29.916667    58.0  30.998750  1011.166667
# 2020-05-17  1010.125000   26.875000    56.0  31.213333  1009.916667
#
#             Humidity_3  month_sin     month_cos
# Date_UTC
# 2020-04-12   32.291667   1.000000  6.123234e-17
# 2020-04-13   27.125000   1.000000  6.123234e-17
# 2020-04-14   25.083333   1.000000  6.123234e-17
# 2020-05-16   26.125000   0.866025 -5.000000e-01
# 2020-05-17   29.916667   0.866025 -5.000000e-01

# %% [markdown]
# # Predicting next day values

# %%
dfX = df.drop(['PM25'], axis =1)

# %%
dfX = dfX.iloc[-1]
dfX
# Out:
# Temp              29.373750
# Humidity          39.000000
# Pressure        1006.000000
# day_week_cat       3.000000
# PM25_1            45.000000
# Temp_1            33.100000
# Pressure_1      1009.000000
# Humidity_1        32.000000
# PM25_2            59.000000
# Temp_2            31.462917
# Pressure_2      1010.125000
# Humidity_2        26.875000
# PM25_3            56.000000
# Temp_3            31.213333
# Pressure_3      1009.916667
# Humidity_3        29.916667
# month_sin          0.866025
# month_cos         -0.500000
# Name: 2020-05-17 00:00:00, dtype: float64

# %%
prediction_lin = regr.predict([dfX])
prediction_nr = mlp.predict([dfX])
prediction_lasso = lasso.predict([dfX])
prediction_elastic = elasticnet.predict([dfX])
prediction_rf = regr_rf.predict([dfX])
prediction_extra_tree = extra_tree.predict([dfX])
prediction_adaboost = tree_2.predict([dfX])
# prediction_xboost = xboost.predict([dfX])

# %%
print ('Linear Regression: ',prediction_lin)
print ('Neural Regression: ',prediction_nr)
print ('Lasso Regression: ',prediction_lasso)
print ('ElasticNet Regression: ',prediction_elastic)
print ('Random Forest Regression: ',prediction_rf)
print ('Extra Trees Regression: ',prediction_extra_tree)
print ('AdaBoost Regression: ',prediction_adaboost)
# print ('XGBoost Regreesion: ',prediction_xboost
# Out:
# Linear Regression:  [40.55755605]
# Neural Regression:  [44.64992893]
# Lasso Regression:  [40.87090747]
# ElasticNet Regression:  [40.73104671]
# Random Forest Regression:  [46.98]
# Extra Trees Regression:  [48.12941176]
# AdaBoost Regression:  [46.]

# %%
df.tail()
# Out:
#             PM25       Temp   Humidity     Pressure  day_week_cat  PM25_1  \
# Date_UTC
# 2020-04-12  58.0  30.998750  26.125000  1011.166667             3    60.0
# 2020-04-13  56.0  31.213333  29.916667  1009.916667             1    58.0
# 2020-04-14  59.0  31.462917  26.875000  1010.125000             5    56.0
# 2020-05-16  45.0  33.100000  32.000000  1009.000000             2    59.0
# 2020-05-17   0.0  29.373750  39.000000  1006.000000             3    45.0
#
#                Temp_1   Pressure_1  Humidity_1  PM25_2     Temp_2  \
# Date_UTC
# 2020-04-12  31.407917  1012.166667   25.083333    57.0  30.697917
# 2020-04-13  30.998750  1011.166667   26.125000    60.0  31.407917
# 2020-04-14  31.213333  1009.916667   29.916667    58.0  30.998750
# 2020-05-16  31.462917  1010.125000   26.875000    56.0  31.213333
# 2020-05-17  33.100000  1009.000000   32.000000    59.0  31.462917
#
#              Pressure_2  Humidity_2  PM25_3     Temp_3   Pressure_3  \
# Date_UTC
# 2020-04-12  1011.291667   27.125000    57.0  28.472083  1011.250000
# 2020-04-13  1012.166667   25.083333    57.0  30.697917  1011.291667
# 2020-04-14  1011.166667   26.125000    60.0  31.407917  1012.166667
# 2020-05-16  1009.916667   29.916667    58.0  30.998750  1011.166667
# 2020-05-17  1010.125000   26.875000    56.0  31.213333  1009.916667
#
#             Humidity_3  month_sin     month_cos
# Date_UTC
# 2020-04-12   32.291667   1.000000  6.123234e-17
# 2020-04-13   27.125000   1.000000  6.123234e-17
# 2020-04-14   25.083333   1.000000  6.123234e-17
# 2020-05-16   26.125000   0.866025 -5.000000e-01
# 2020-05-17   29.916667   0.866025 -5.000000e-01

# %% [markdown]
# # Preparing CSV files for execution on the next day

# %%
dfDel = pd.read_csv(r"/Users/dhruv/Downloads/BE_PROJECT_CSV/PyScript/datasetRawAdded2.csv", index_col="Date_UTC")

# %%
dfDel = dfDel[:-1]

# %%
dfDel.to_csv(r"/Users/dhruv/Downloads/BE_PROJECT_CSV/PyScript/datasetRawAdded2.csv")

# %%
dfDel2 = pd.read_csv(r"/Users/dhruv/Downloads/BE_PROJECT_CSV/PyScript/clairityCleanedAdded2.csv", index_col="Date_UTC")

# %%
dfDel2 = dfDel2[:-1]
dfDel2.tail()
# Out:
#             PM25       Temp   Humidity     Pressure  day_week_cat  PM25_1  \
# Date_UTC
# 2020-04-11  60.0  31.407917  25.083333  1012.166667             2    57.0
# 2020-04-12  58.0  30.998750  26.125000  1011.166667             3    60.0
# 2020-04-13  56.0  31.213333  29.916667  1009.916667             1    58.0
# 2020-04-14  59.0  31.462917  26.875000  1010.125000             5    56.0
# 2020-05-16  45.0  33.100000  32.000000  1009.000000             2    59.0
#
#                Temp_1   Pressure_1  Humidity_1  PM25_2     Temp_2  \
# Date_UTC
# 2020-04-11  30.697917  1011.291667   27.125000    57.0  28.472083
# 2020-04-12  31.407917  1012.166667   25.083333    57.0  30.697917
# 2020-04-13  30.998750  1011.166667   26.125000    60.0  31.407917
# 2020-04-14  31.213333  1009.916667   29.916667    58.0  30.998750
# 2020-05-16  31.462917  1010.125000   26.875000    56.0  31.213333
#
#              Pressure_2  Humidity_2  PM25_3     Temp_3   Pressure_3  \
# Date_UTC
# 2020-04-11  1011.250000   32.291667    44.0  27.388333  1012.333333
# 2020-04-12  1011.291667   27.125000    57.0  28.472083  1011.250000
# 2020-04-13  1012.166667   25.083333    57.0  30.697917  1011.291667
# 2020-04-14  1011.166667   26.125000    60.0  31.407917  1012.166667
# 2020-05-16  1009.916667   29.916667    58.0  30.998750  1011.166667
#
#             Humidity_3  month_sin     month_cos
# Date_UTC
# 2020-04-11   29.666667   1.000000  6.123234e-17
# 2020-04-12   32.291667   1.000000  6.123234e-17
# 2020-04-13   27.125000   1.000000  6.123234e-17
# 2020-04-14   25.083333   1.000000  6.123234e-17
# 2020-05-16   26.125000   0.866025 -5.000000e-01

# %%
dfDel2.to_csv(r"/Users/dhruv/Downloads/BE_PROJECT_CSV/PyScript/clairityCleanedAdded2.csv")
